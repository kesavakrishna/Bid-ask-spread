# %% [markdown]
# <a href="https://colab.research.google.com/github/kesavakrishna/Bid-ask-spread/blob/main/Bibliometric%20Analysis/code/slr_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


input_paper1 = pd.read_csv('/content/scopus 112_bidask.csv')
input_paper2 = pd.read_csv('/content/scopus 21bid_ask.csv')

# input paper data into a single dataframe
all_papers = pd.concat([input_paper1, input_paper2], ignore_index=True)
author_names = all_papers['Authors'].tolist()

print('All Author Names:')
for author in author_names:
    print(author)
# Out:
# All Author Names:
# Yamphram P., Sutthimat P., Rakwongwan U.
# Liao Y.-H., Lee H., Chen C.-J.
# Zhao W., Gao Y., Wang M.
# Chen B.
# Pan A., Misra A.K.
# Almulhim A.A.
# Guo X., Lehalle C.-A., Xu R.
# Gao Y., Zhao W., Wang M.
# Morariu-Patrichi M., Pakkanen M.S.
# Hagströmer B.
# Su E., Tokmakcioglu K.
# Tsai P.-C., Tsai C.-M.
# Maciak M.
# Hu Q., Newton D.
# Romito S., Vurro C.
# Brauneis A., Mestel R., Theissen E.
# Chuanhai Z.
# Alizadeh S., Tash M.N.S., Roshan R.
# Clinet S., Potiron Y.
# Gu X., Mamon R., Davison M., Yu H.
# Le H., Gregoriou A.
# Ichimura D., Videira R., Ripamonti A.
# Aflatooni A., Khazaei M.
# Fathi S., Jalali S., Ajam A., Sadeghi O.M.
# Liu W., Wan D., Chen W.
# Gao Y., Wang M., Wang Y.
# Lapshin V.
# Han Y., Shao X.-F., Cui X., Yue X.-G., Bwalya K.J., Manta O.
# Gao Y., Li Y., Wang Y., Wang C., Liu C.
# Glanzer M., Pflug G.C., Pichler A.
# How C.C., Tsen W.H.
# Chen X., Linton O., Schneeberger S., Yi Y.
# Będowska-Sójka B.
# Li Z., Lambe B., Adegbite E.
# ...
